# %%
import os
import sys
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.exc import SQLAlchemyError
import seaborn as sns
import matplotlib.pyplot as plt
import mysql.connector as msql
from mysql.connector import Error
import csv

# %%
df = pd.read_csv("D:\work\processed_telecom.csv")
df.head()
# Out:
#    MSISDN_Number  No_of_xDRsessions  Session_Duration_s     Total_MB  \
# 0   3.360100e+10                  1             116.720   878.690574
# 1   3.360100e+10                  1             181.230   156.859643
# 2   3.360100e+10                  1             134.969   595.966483
# 3   3.360101e+10                  1              49.878   422.320698
# 4   3.360101e+10                  2              37.104  1457.410944
#
#    Social_Media_MB  Google_MB  Email_MB  Youtube_MB  Netflix_MB    Gaming_MB  \
# 0         2.232135   4.389005  1.331362   21.624548   27.180981   812.458661
# 1         2.660565   5.334863  3.307781   12.432223   11.221763   119.750078
# 2         3.195623   3.443126  3.205380   21.333570   19.353900   538.827713
# 3         0.280294   9.678493  2.284670    6.977321    1.942092   391.126127
# 4         2.912542  18.499616  3.305469   41.533002   49.201724  1314.797820
#
#      Other_MB  DecileRank
# 0  386.570872           2
# 1  281.710071           4
# ...

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE telecoms")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Error while connecting to MySQL 1007 (HY000): Can't create database 'telecoms'; database exists

# %%
# !pip install mysql-connector-python
# !pip install pymysql
import pymysql
pymysql.install_as_MySQLdb()

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', database='telecoms', user='root', password='')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS telecom5;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE telecom5(MSISDN_Number varchar(30), No_of_xDRsessions varchar(255), Session_Duration_s varchar(255), Gaming_MB varchar(30),Social_Media_MB varchar(30),Google_MB varchar(30),Email_MB varchar(30),Youtube_MB varchar(30),Netflix_MB varchar(30),Total_MB varchar(30),Other_MB varchar(30), DecileRank varchar(30))") 
        print("Table is created....")
      
        #loop through the data frame
        for i,row in df.iterrows():
            #here %S means string values 
            sql = "INSERT INTO telecoms.telecom5 VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
          
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
           
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('telecoms',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
cursor.close()
conn.close()
